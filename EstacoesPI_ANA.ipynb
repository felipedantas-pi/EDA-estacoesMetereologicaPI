# %%
import pandas as pd
import geopandas as gpd
#import pyarrow.parquet as pq

# %%
path_est = './dados/ana/EFPR_BR.parquet'

# %%
gdf_est = gpd.read_parquet(path_est)

# %%
uf = 'PI'
estPI = gdf_est.query('ESTADO == @uf')
estPI
# Out:
#        EST_ID  REGISTROID                            BACIA
# 172     35347     3737504  ATLÂNTICO,TRECHO NORTE/NORDESTE  \
# 173     35295     3737505  ATLÂNTICO,TRECHO NORTE/NORDESTE
# 176     32126    53704038  ATLÂNTICO,TRECHO NORTE/NORDESTE
# 177     32207    53704039  ATLÂNTICO,TRECHO NORTE/NORDESTE
# 178     35290    53704040  ATLÂNTICO,TRECHO NORTE/NORDESTE
# ...       ...         ...                              ...
# 14011    3142     3731067  ATLÂNTICO,TRECHO NORTE/NORDESTE
# 14012    3141     3731066  ATLÂNTICO,TRECHO NORTE/NORDESTE
# 14015    3147    53078498  ATLÂNTICO,TRECHO NORTE/NORDESTE
# 14017    3128     3731068  ATLÂNTICO,TRECHO NORTE/NORDESTE
# 14018    3033     3731072  ATLÂNTICO,TRECHO NORTE/NORDESTE
#
#                        RIO ESTADO              MUNICIPIO RESPONSAVE
# 172                   None     PI           LUÍS CORREIA      DNOCS  \
# 173                   None     PI               PARNAÍBA      INMET
# ...

# %%
estPI.to_parquet('./dados/ana/EFPR_PI.parquet')
