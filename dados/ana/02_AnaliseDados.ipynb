# %%
import geopandas as gpd
import pandas as pd

# %%
gdf = gpd.read_parquet("./EstacoesFluvioPluvio_PiauiOperando.parquet")

# %%
gdf.head()
# Out:
#       OBJECTID                  Nome    TipoEstacao  TipoEstacaoCodigo  \
# 1599      1600     FAZENDA BANANEIRA  Fluviométrica                  1
# 1601      1602              BARROCÃO  Fluviométrica                  1
# 1602      1603              CONTRATO  Fluviométrica                  1
# 1603      1604             BOA VISTA  Fluviométrica                  1
# 1604      1605  REDENÇÃO DO GURGUÉIA  Fluviométrica                  1
#
#      Operando CodigoAdicional  Latitude  Longitude  Altitude  AreaDrenagem  \
# 1599      Sim            None  -10.0164 -45.024700     420.0         681.0
# 1601      Sim            None   -9.8819 -45.232800     392.0         916.0
# 1602      Sim            None   -9.5800 -45.029200     341.0         750.0
# 1603      Sim            None   -9.6500 -44.833333       NaN        3660.0
# 1604      Sim             ANA   -9.5397 -44.601400     270.0       22700.0
#
#       ... RedeNavegacao  RedeCursoDagua RedeEstrategica  RedeCaptacao  \
# ...

# %%
gdf.columns
# Out:
# Index(['OBJECTID', 'Nome', 'TipoEstacao', 'TipoEstacaoCodigo', 'Operando',
#        'CodigoAdicional', 'Latitude', 'Longitude', 'Altitude', 'AreaDrenagem',
#        'Bacia', 'BaciaCodigo', 'SubBacia', 'SubBaciaCodigo', 'Rio',
#        'RioCodigo', 'UF', 'UFCodigo', 'Municipio', 'MunicipioCodigo',
#        'Responsavel', 'ResponsavelSigla', 'ResponsavelCodigo',
#        'ResponsavelUnidade', 'Operadora', 'OperadoraSigla', 'OperadoraCodigo',
#        'OperadoraUnidade', 'OperadoraRoteiro', 'EscalaNivel',
#        'EscalaNivelInicio', 'EscalaNivelFim', 'RegistradorNivel',
#        'RegistradorNivelInicio', 'RegistradorNivelFim',
#        'MedicaoDescargaLiquida', 'MedicaoDescargaLiquidaInicio',
#        'MedicaoDescargaLiquidaInicioFim', 'MedicaoDescargaSolida',
#        'MedicaoDescargaSolidaInicio', 'MedicaoDescargaSolidaFim', 'MedicaoQA',
#        'MedicaoQAInicio', 'MedicaoQAFim', 'PluviometroConvencional',
#        'PluviometroConvencionalInicio', 'PluviometroConvencionalFim',
# ...

# %%
gdf.TipoEstacao.unique()
# Out:
# array(['Fluviométrica', 'Pluvometrica'], dtype=object)

# %%
tpEst = 'Pluvometrica'
gdf_p = gdf.query('TipoEstacao == @tpEst')

# %%
gdf_p.crs
# Out:
# <Geographic 2D CRS: EPSG:4674>
# Name: SIRGAS 2000
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: Latin America - Central America and South America - onshore and offshore. Brazil - onshore and offshore.
# - bounds: (-122.19, -59.87, -25.28, 32.72)
# Datum: Sistema de Referencia Geocentrico para las AmericaS 2000
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
gdf_p.to_crs(epsg=5880, inplace=True)
# Out:
# C:\Users\labgeo\workspace\github\estacoesMetereoligicas-piaui\.venv\Lib\site-packages\geopandas\geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
gdf_p.crs
# Out:
# <Projected CRS: EPSG:5880>
# Name: SIRGAS 2000 / Brazil Polyconic
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: Brazil - onshore and offshore. Includes Rocas, Fernando de Noronha archipelago, Trindade, Ihlas Martim Vaz and Sao Pedro e Sao Paulo.
# - bounds: (-74.01, -35.71, -25.28, 7.04)
# Coordinate Operation:
# - name: Brazil Polyconic
# - method: American Polyconic
# Datum: Sistema de Referencia Geocentrico para las AmericaS 2000
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
gdf_p.buffer(25000).explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
